# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import pandas as pd

# Install: pip install vaderSentiment

analyzer = SentimentIntensityAnalyzer()

posts_df = pd.read_csv('svb_reddit_posts.csv')

emotions = []
for idx, row in posts_df.iterrows():
    text = str(row['full_text'])[:512]
    scores = analyzer.polarity_scores(text)
    emotions.append({
        'post_id': row['id'],
        'timestamp': row['timestamp'],
        'text': text,
        **scores
    })

df = pd.DataFrame(emotions)
df.to_csv('svb_posts_sentiment.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
#       2 import pandas as pd
#       4 # Install: pip install vaderSentiment
#
# ModuleNotFoundError: No module named 'vaderSentiment'
